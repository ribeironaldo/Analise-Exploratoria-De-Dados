# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
A = [9.2, 10.8, 10.6, 11.1, 12.1, 9.6, 11.2, 8.4, 12.9, 12.1, 14.4, 11.1, 11.1, 9.7, 8.4, 12.3, 10.7, 12.9, 9.1, 12.8]
B = [12.5, 18.5, 21.3, 14.3, 18.5, 19.0, 10.8, 23.1, 17.4, 10.7, 14.3, 16.3, 18.0, 7.1, 12.8, 14.7, 11.3, 8.2, 13.8]
C = [21.3, 28.7, 15.8, 24.0, 13.7, 18.1, 12.6, 14.6, 6.1, 19.8, 22.3, 15.7, 16.3, 18.2, 15.7, 6.6, 9.3, 1.3, 19.0]
D = [13.7, 8.6, 14.9, 10.2, 14.0, 10.5, 15.0, 5.2, 10.0, 11.7, 18.7, 9.3, 7.9, 6.5, 11.5, 12.0, 8.3, 8.3, 9.8, 4.7]

a = plt.hist(A, 15)
plt.axvline(np.mean(A), color='b', linestyle='dashed', linewidth=2)
plt.axvline(np.median(A), color='r', linestyle='dashed', linewidth=2)
plt.title("Média e Mediana no Área A")
plt.xlabel("Altura - Metros")
plt.ylabel("Frequência")
plt.show()
media = np.mean(A)
mediana = np.median(A)
moda = stats.mode(A)
print("Média:", media, "Mediana:", mediana, "Moda:", moda[0])

a = plt.hist(B, 15)
plt.axvline(np.mean(B), color='b', linestyle='dashed', linewidth=2)
plt.axvline(np.median(B), color='r', linestyle='dashed', linewidth=2)
plt.title("Média e Mediana no Área B")
plt.xlabel("Altura - Metros")
plt.ylabel("Frequência")
plt.show()
media = np.mean(B)
mediana = np.median(B)
moda = stats.mode(B)
print("Média:", media, "Mediana:", mediana, "Moda:", moda[0])

a = plt.hist(C, 15)
plt.axvline(np.mean(C), color='b', linestyle='dashed', linewidth=2)
plt.axvline(np.median(C), color='r', linestyle='dashed', linewidth=2)
plt.title("Média e Mediana no Área C")
plt.xlabel("Altura - Metros")
plt.ylabel("Frequência")
plt.show()
media = np.mean(C)
mediana = np.median(C)
moda = stats.mode(C)
print("Média:", media, "Mediana:", mediana, "Moda:", moda[0])

a = plt.hist(D, 15)
plt.axvline(np.mean(D), color='b', linestyle='dashed', linewidth=2)
plt.axvline(np.median(D), color='r', linestyle='dashed', linewidth=2)
plt.title("Média e Mediana no Área D")
plt.xlabel("Altura - Metros")
plt.ylabel("Frequência")
plt.show()
media = np.mean(D)
mediana = np.median(D)
moda = stats.mode(D)
print("Média:", media, "Mediana:", mediana, "Moda:", moda[0])
# Out:
# Média: 11.025 Mediana: 11.1 Moda: [ 11.1]
# Média: 14.8736842105 Mediana: 14.3 Moda: [ 14.3]
# Média: 15.7421052632 Mediana: 15.8 Moda: [ 15.7]
# Média: 10.54 Mediana: 10.1 Moda: [ 8.3]
